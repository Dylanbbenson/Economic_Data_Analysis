# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

plt.style.use('fivethirtyeight')
#color_pad = plt.rcParams['axes.prod_cycle'].by_key()['color']
from fredapi import Fred

# %%
#set Fred api key
fred_key = '635735e8d833607369c43a9d7f98dcd9'
fred = Fred(fred_key)

# %%
DJfred.search('Dow Jones')
# Out:
#                                 id realtime_start realtime_end  \
# series id
# DJIA                          DJIA     2023-03-05   2023-03-05
# M1109BUSM293NNBR  M1109BUSM293NNBR     2023-03-05   2023-03-05
# M1109AUSM293NNBR  M1109AUSM293NNBR     2023-03-05   2023-03-05
# DTP10J28                  DTP10J28     2023-03-05   2023-03-05
# DJTA                          DJTA     2023-03-05   2023-03-05
# ...                            ...            ...          ...
# MNXRPSNSA                MNXRPSNSA     2023-03-05   2023-03-05
# TPXRPSNSA                TPXRPSNSA     2023-03-05   2023-03-05
# CEXRPSNSA                CEXRPSNSA     2023-03-05   2023-03-05
# POXRPSNSA                POXRPSNSA     2023-03-05   2023-03-05
# M13022USM156NNBR  M13022USM156NNBR     2023-03-05   2023-03-05
#
#                                                               title  \
# series id
# DJIA                                   Dow Jones Industrial Average
# M1109BUSM293NNBR  Dow-Jones Industrial Stock Price Index for Uni...
# M1109AUSM293NNBR  Dow-Jones Industrial Stock Price Index for Uni...
# DTP10J28          10-Year 0.5% Treasury Inflation-Indexed Note, ...
# DJTA                               Dow Jones Transportation Average
# ...                                                             ...
# MNXRPSNSA         Home Price Sales Pair Counts for Minneapolis, ...
# TPXRPSNSA           Home Price Sales Pair Counts for Tampa, Florida
# CEXRPSNSA          Home Price Sales Pair Counts for Cleveland, Ohio
# POXRPSNSA         Home Price Sales Pair Counts for Portland, Oregon
# M13022USM156NNBR  Railroad Bond Yields, Second Grade for United ...
#
#                  observation_start observation_end     frequency  \
# series id
# DJIA                    2013-03-04      2023-03-03  Daily, Close
# M1109BUSM293NNBR        1914-12-01      1968-12-01       Monthly
# M1109AUSM293NNBR        1897-01-01      1916-09-01       Monthly
# DTP10J28                2018-01-19      2023-03-02         Daily
# DJTA                    2013-03-04      2023-03-03  Daily, Close
# ...                            ...             ...           ...
# MNXRPSNSA               1989-01-01      2022-12-01       Monthly
# TPXRPSNSA               1987-01-01      2022-12-01       Monthly
# CEXRPSNSA               1987-01-01      2022-12-01       Monthly
# POXRPSNSA               1987-01-01      2022-12-01       Monthly
# M13022USM156NNBR        1915-01-01      1938-07-01       Monthly
#
#                  frequency_short              units  units_short  \
# series id
# DJIA                           D              Index        Index
# M1109BUSM293NNBR               M  Dollars per Share  $ Per Share
# M1109AUSM293NNBR               M  Dollars per Share  $ Per Share
# DTP10J28                       D            Percent            %
# DJTA                           D              Index        Index
# ...                          ...                ...          ...
# MNXRPSNSA                      M              Units        Units
# TPXRPSNSA                      M              Units        Units
# CEXRPSNSA                      M              Units        Units
# POXRPSNSA                      M              Units        Units
# M13022USM156NNBR               M            Percent            %
#
#                       seasonal_adjustment seasonal_adjustment_short  \
# series id
# DJIA              Not Seasonally Adjusted                       NSA
# M1109BUSM293NNBR  Not Seasonally Adjusted                       NSA
# M1109AUSM293NNBR  Not Seasonally Adjusted                       NSA
# DTP10J28          Not Seasonally Adjusted                       NSA
# DJTA              Not Seasonally Adjusted                       NSA
# ...                                   ...                       ...
# MNXRPSNSA         Not Seasonally Adjusted                       NSA
# TPXRPSNSA         Not Seasonally Adjusted                       NSA
# CEXRPSNSA         Not Seasonally Adjusted                       NSA
# POXRPSNSA         Not Seasonally Adjusted                       NSA
# M13022USM156NNBR  Not Seasonally Adjusted                       NSA
#
#                                last_updated popularity  \
# series id
# DJIA              2023-03-03 19:01:02-06:00         73
# M1109BUSM293NNBR  2012-08-15 15:02:00-05:00         51
# M1109AUSM293NNBR  2012-08-15 15:01:12-05:00         15
# DTP10J28          2023-03-03 06:02:06-06:00         55
# DJTA              2023-03-03 19:01:02-06:00         38
# ...                                     ...        ...
# MNXRPSNSA         2023-02-28 08:03:18-06:00          1
# TPXRPSNSA         2023-02-28 08:03:15-06:00          1
# CEXRPSNSA         2023-02-28 08:03:16-06:00          1
# POXRPSNSA         2023-02-28 08:03:19-06:00          1
# M13022USM156NNBR  2012-08-20 08:18:48-05:00          1
#
#                                                               notes
# series id
# DJIA              The observations for the Dow Jones Industrial ...
# M1109BUSM293NNBR  Series Is Presented Here As Two Variables--(1)...
# M1109AUSM293NNBR  Series Is Presented Here As Two Variables--(1)...
# DTP10J28          Yield to maturity on accrued principal. Treasu...
# DJTA              The observations for the Dow Jones Transportat...
# ...                                                             ...
# MNXRPSNSA         For more information regarding the index, plea...
# TPXRPSNSA         For more information regarding the index, plea...
# CEXRPSNSA         For more information regarding the index, plea...
# POXRPSNSA         For more information regarding the index, plea...
# M13022USM156NNBR  Source: Dow Jones  This NBER data series m1302...
#
# [276 rows x 15 columns]
